# %%
import kagglehub

path = kagglehub.dataset_download("annavictoria/speed-dating-experiment")

# %%
import pandas as pd
file_path = path + "/Speed Dating Data.csv"
print(file_path)
df = pd.read_csv(file_path, encoding='latin-1')
df.head()
# Out:
# C:\Users\krhij\.cache\kagglehub\datasets\annavictoria\speed-dating-experiment\versions\1/Speed Dating Data.csv
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4  ...
# 1    1  1.0       0    1       1     1     10         7       NaN      3  ...
# 2    1  1.0       0    1       1     1     10         7       NaN     10  ...
# 3    1  1.0       0    1       1     1     10         7       NaN      5  ...
# 4    1  1.0       0    1       1     1     10         7       NaN      7  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  \
# 0      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 1      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 2      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 3      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# ...

# %%
#Time1
columns_Time1 = ['iid', 'pid']
for col in df.columns:
    if col.endswith('1_1'):
        columns_Time1.append(col)
df_pre_event = df[columns_Time1]

#Scorecard
columns_scorecard = ['iid', 'pid', 'attr', 'sinc', 'intel', 'fun', 'amb', 'shar', 'dec', 'match']
df_scorecard = df[columns_scorecard]

#Half-way
columns_Halfway = ['iid', 'pid']
for col in df.columns:
    if col.endswith('1_s'):
        columns_Halfway.append(col)
df_halfway = df[columns_Halfway]

#Time2
columns_Time2 = ['iid', 'pid']
for col in df.columns:
    if col.endswith('1_2'):
        columns_Time2.append(col)
df_day_after = df[columns_Time2]

#Time3
columns_Time3 = ['iid', 'pid']
for col in df.columns:
    if col.endswith('1_3'):
        columns_Time3.append(col)
df_weeks_later = df[columns_Time3]


print("Pre-Event Survey Data ---")
display(df_pre_event.head(3))

print("\nIn-Event Scorecard (The Date) ---")
display(df_scorecard.head(3))

print("\nHalfway Survey Data ---")
display(df_halfway.head(3))

print("\nDay-After Survey Data ---")
display(df_day_after.head(3))

print("\n3-4 Weeks Later Survey Data ---")
display(df_weeks_later.head(3))
# Out:
# Pre-Event Survey Data ---
#    iid   pid  attr1_1  sinc1_1  intel1_1  fun1_1  amb1_1  shar1_1
# 0    1  11.0     15.0     20.0      20.0    15.0    15.0     15.0
# 1    1  12.0     15.0     20.0      20.0    15.0    15.0     15.0
# 2    1  13.0     15.0     20.0      20.0    15.0    15.0     15.0
# In-Event Scorecard (The Date) ---
#    iid   pid  attr  sinc  intel  fun  amb  shar  dec  match
# 0    1  11.0   6.0   9.0    7.0  7.0  6.0   5.0    1      0
# 1    1  12.0   7.0   8.0    7.0  8.0  5.0   6.0    1      0
# 2    1  13.0   5.0   8.0    9.0  8.0  5.0   7.0    1      1
# Halfway Survey Data ---
#    iid   pid  attr1_s  sinc1_s  intel1_s  fun1_s  amb1_s  shar1_s
# 0    1  11.0      NaN      NaN       NaN     NaN     NaN      NaN
# 1    1  12.0      NaN      NaN       NaN     NaN     NaN      NaN
# 2    1  13.0      NaN      NaN       NaN     NaN     NaN      NaN
# Day-After Survey Data ---
#    iid   pid  attr1_2  sinc1_2  intel1_2  fun1_2  amb1_2  shar1_2
# ...

# %%
print("Dataset Shape:", df.shape)

df.info(verbose=True, show_counts=True)
# Out:
# Dataset Shape: (8378, 195)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8378 entries, 0 to 8377
# Data columns (total 195 columns):
#  #    Column    Non-Null Count  Dtype
# ---   ------    --------------  -----
#  0    iid       8378 non-null   int64
#  1    id        8377 non-null   float64
#  2    gender    8378 non-null   int64
#  3    idg       8378 non-null   int64
#  4    condtn    8378 non-null   int64
#  5    wave      8378 non-null   int64
#  6    round     8378 non-null   int64
#  7    position  8378 non-null   int64
#  8    positin1  6532 non-null   float64
#  9    order     8378 non-null   int64
#  10   partner   8378 non-null   int64
#  11   pid       8368 non-null   float64
#  12   match     8378 non-null   int64
#  13   int_corr  8220 non-null   float64
#  14   samerace  8378 non-null   int64
#  15   age_o     8274 non-null   float64
#  16   race_o    8305 non-null   float64
#  17   pf_o_att  8289 non-null   float64
#  18   pf_o_sin  8289 non-null   float64
# ...

# %%
df.describe().T
# Out:
#            count        mean         std  min    25%    50%    75%    max
# iid       8378.0  283.675937  158.583367  1.0  154.0  281.0  407.0  552.0
# id        8377.0    8.960248    5.491329  1.0    4.0    8.0   13.0   22.0
# gender    8378.0    0.500597    0.500029  0.0    0.0    1.0    1.0    1.0
# idg       8378.0   17.327166   10.940735  1.0    8.0   16.0   26.0   44.0
# condtn    8378.0    1.828837    0.376673  1.0    2.0    2.0    2.0    2.0
# ...          ...         ...         ...  ...    ...    ...    ...    ...
# attr5_3   2016.0    6.810020    1.507341  2.0    6.0    7.0    8.0   10.0
# sinc5_3   2016.0    7.615079    1.504551  2.0    7.0    8.0    9.0   10.0
# intel5_3  2016.0    7.932540    1.340868  4.0    7.0    8.0    9.0   10.0
# fun5_3    2016.0    7.155258    1.672787  1.0    6.0    7.0    8.0   10.0
# amb5_3    2016.0    7.048611    1.717988  1.0    6.0    7.0    8.0   10.0
#
# [187 rows x 8 columns]

# %%
missing_percentages = (df.isnull().sum() / len(df)) * 100
missing_data = missing_percentages[missing_percentages > 0].sort_values(ascending=False)

print("Columns with most missing data:")
print(missing_data.head(10))
# Out:
# Columns with most missing data:
# num_in_3    92.026737
# numdat_3    82.143710
# expnum      78.515159
# sinc7_2     76.665075
# amb7_2      76.665075
# shar7_2     76.438291
# fun7_2      76.318931
# attr7_2     76.318931
# intel7_2    76.318931
# amb7_3      75.936978
# dtype: float64

# %%
print("Total Match Count:")
print(df['match'].value_counts())

print("\nMatch Percentage:")
print(df['match'].value_counts(normalize=True) * 100)
# Out:
# Total Match Count:
# match
# 0    6998
# 1    1380
# Name: count, dtype: int64
#
# Match Percentage:
# match
# 0    83.528288
# 1    16.471712
# Name: proportion, dtype: float64
